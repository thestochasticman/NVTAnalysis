# %%
import os
# os.chdir('/g/data/xe2/ya6227/NVTAnalysis')
os.chdir('/borevitz_projects/repos/NVTAnalysis')
from daesim2_analysis.parameters import Parameters
from daesim2_analysis.daesim_config import DAESIMConfig
from NVTAnalysis.get_n_representative_sites import get_n_representative_sites
from NVTAnalysis.compare_pre_and_post_calibration import compare_pre_and_post_calibration

# %%
data_dir = '/borevitz_projects/data'
#data_dir = '/g/data/xe2/ya6227/NVTAnalysis/data/DAESim'
tmp_dir = data_dir
out_dir = data_dir
experiment_df, queries = get_n_representative_sites(tmp_dir=tmp_dir, out_dir=out_dir)

# %%
# Out:
#                Method  RowID  Unnamed: 0  Year Crop.Name State     RegionName  \
# 0  Bayesian D-optimal     27        4924  2020    Canola    SA  Murray Mallee
# 1  Bayesian D-optimal    190       11137  2023    Canola    SA        Yorke P
# 2  Bayesian D-optimal     56        5770  2020    Canola    WA        Agzone4
# 3  Bayesian D-optimal    110        7867  2022    Canola   NSW            N/E
# 4  Bayesian D-optimal     92        7058  2021    Canola   VIC        Wimmera
# 5  Bayesian D-optimal    223       12564  2023    Canola    WA        Agzone6
# 6  Bayesian D-optimal     49        5567  2020    Canola    WA        Agzone2
# 7  Bayesian D-optimal      1        2997  2019    Canola   NSW            S/W
# 8  Bayesian D-optimal    207       11908  2023    Canola    WA        Agzone2
# 9  Bayesian D-optimal    192       11226  2023    Canola   VIC         Mallee
#
#    SiteDescription    TrialCode                  SeriesName  ...  \
# 0          Lameroo  CLTA20LAME5   Low-Med Rainfall Triazine  ...
# 1        Arthurton  CHTA23ARTH5  Med-High Rainfall Triazine  ...
# 2        Bencubbin  CLTA20BENC6   Low-Med Rainfall Triazine  ...
# 3       Wellington  CHTA22WELL2  Med-High Rainfall Triazine  ...
# 4          Minimay  CHTA21MINI3  Med-High Rainfall Triazine  ...
# 5  Stirlings South  CHTA23ST.S6  Med-High Rainfall Triazine  ...
# 6          Nyabing  CLTA20NYAB6   Low-Med Rainfall Triazine  ...
# 7         Lockhart  CHTA19LOCK2  Med-High Rainfall Triazine  ...
# 8       Dalwallinu  CLTA23DALW6   Low-Med Rainfall Triazine  ...
# 9         Hopetoun  CLTA23HOPE3   Low-Med Rainfall Triazine  ...
#
#            Probability Error Mean Squared  1000 grain weight  \
# 0  0.00293917071115894           0.005950                NaN
# 1    0.426832442176318           0.029504                NaN
# 2   0.0461486520610291           0.027675                NaN
# 3  0.00669861020731496           0.053748                NaN
# 4  0.00533978636842773           0.054877                3.3
# 5               <0.001           0.039845                NaN
# 6  0.00526535230215402           0.020474                NaN
# 7               <0.001           0.011656                NaN
# 8               <0.001           0.000863                NaN
# 9               <0.001           0.006777                NaN
#
#    Protein - Seed (raw) Protein Meal (10% moisture) Glucosinolate  \
# 0                 29.80                   48.763636           NaN
# 1                   NaN                         NaN           NaN
# 2                 26.50                   46.131528           NaN
# 3                 22.25                   43.055256           NaN
# 4                 25.10                   45.089820           NaN
# 5                 23.00                   43.125000           NaN
# 6                 25.90                   45.705882           NaN
# 7                 31.48                   48.142736           NaN
# 8                   NaN                         NaN           NaN
# 9                 29.70                   44.924369           NaN
#
#    Grain Moisture Content  Oil - Seed (6% moisture)  Oil (raw)  \
# 0                    5.50                 39.291005      39.50
# 1                     NaN                       NaN        NaN
# 2                    6.10                 42.244941      42.20
# 3                    4.64                 48.153313      48.85
# 4                    4.70                 44.583420      45.20
# 5                    6.20                 45.897654      45.80
# 6                    5.80                 43.108280      43.20
# 7                    5.59                 35.405571      35.56
# 8                     NaN                       NaN        NaN
# 9                    7.70                 33.404117      32.80
#
#    Protein Seed (10% moisture)
# 0                    28.380952
# 1                          NaN
# 2                    25.399361
# 3                    20.999370
# 4                    23.704092
# 5                    22.068230
# 6                    24.745223
# 7                    30.009533
# 8                          NaN
# 9                    28.959913
#
# [10 rows x 39 columns]

# %%
daesim_config: DAESIMConfig=DAESIMConfig.from_json_dict('daesim_configs/DAESIM1.json')
parameters: Parameters=Parameters.__from_file__('parameters/PARAMS1.json')

# %%
parameters: Parameters=Parameters.__from_file__('parameters/PARAMS1.json')

# %%
experiment_df[experiment_df['TrialCode'] == queries[0].stub]['Single Site Yield'].iloc[0]
# experiment_df['Single Site Yield']
# Out:
# 1.074035

# %%
compare_pre_and_post_calibration(queries[2], daesim_config, parameters)
# Out:
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code

# %%
for query in queries:
    daesim_config: DAESIMConfig=DAESIMConfig.from_json_dict('daesim_configs/DAESIM1.json')
    parameters: Parameters=Parameters.__from_file__('parameters/PARAMS1.json')
    compare_pre_and_post_calibration(query, daesim_config, parameters)
# Out:
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/NVTAnalysis/NVTAnalysis/compare_pre_and_post_calibration.py:70: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, axes = plt.subplots(5,1,figsize=(8,10),sharex=True)
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/scipy/optimize/_differentialevolution.py:486: UserWarning: differential_evolution: the 'workers' keyword has overridden updating='immediate' to updating='deferred'
#   with DifferentialEvolutionSolver(func, bounds, args=args,
# /g/data/xe2/ya6227/miniconda3/envs/PaddockTSEnv/lib/python3.10/site-packages/daesim/plantcarbonwater.py:459: RuntimeWarning: divide by zero encountered in divide
#   r_ws = (airP/(self.Site.R_w_mol*(leafTempC+273.15)))/gsw    ## converts stomatal conductance (mol H2O m-2 s-1) to stomatal resistance (s m-1)  (see Nobel (2009) Section 8.1F) TODO: Check this and cross-check it with calculations of stomatal resistance in leafgasexchange modules and perhaps also SCOPE model code
